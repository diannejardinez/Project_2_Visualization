# %%
import os

import pandas as pd
# import numpy as np

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine


from flask import Flask, jsonify, render_template
from sqlalchemy import inspect

# %%
engine = create_engine("postgresql://postgres:postgres@localhost:5432/Olympics")

# %%
conn = engine.connect()

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['athletes']

# %%
columns = inspector.get_columns('athletes')
for column in columns:
    print(column["name"], column["type"])
# Out:
# sno INTEGER
# id INTEGER
# name VARCHAR
# sex VARCHAR(1)
# age DOUBLE PRECISION
# height DOUBLE PRECISION
# weight DOUBLE PRECISION
# country VARCHAR
# noc VARCHAR
# games VARCHAR
# year INTEGER
# season VARCHAR
# city VARCHAR
# sport VARCHAR
# event VARCHAR
# medal VARCHAR

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['athletes']

# %%
Athletes = Base.classes.athletes

# %%
session = Session(bind=engine)

# %%
for result in session.query(Athletes).all():
    print(result.name)
    break
# Out:
# A Dijiang

# %%
sel = [
    Athletes.id,
    Athletes.name,
    Athletes.sex,
    Athletes.age,
    Athletes.height,
    Athletes.weight, 
    Athletes.country,
    Athletes.noc,
    Athletes.games,
    Athletes.year,
    Athletes.season,
    Athletes.city,
    Athletes.sport,
    Athletes.event,
    Athletes.medal
    ]

# %%
results = session.query(*sel).all()

# %%
all_athletes = []
for id, name, sex, age, height, weight, country, noc, games, year, season, city, sport, event, medal in results:
        altlete_dict = {}
        altlete_dict["name"] = name
        altlete_dict["sex"] = sex
        altlete_dict["age"] = age
        altlete_dict["height"] = height
        altlete_dict["weight"] = weight
        altlete_dict["country"] = country
        altlete_dict["noc"] = noc
        altlete_dict["games"] = games
        altlete_dict["year"] = year
        altlete_dict["season"] = season
        altlete_dict["city"] = city
        altlete_dict["sport"] = sport
        altlete_dict["event"] = event
        altlete_dict["medal"] = medal

        all_athletes.append(altlete_dict)

# %%
all_athletes
# Out:
# [{'name': 'A Dijiang',
#   'sex': 'M',
#   'age': 24.0,
#   'height': 180.0,
#   'weight': 80.0,
#   'country': 'China',
#   'noc': 'CHN',
#   'games': '1992 Summer',
#   'year': 1992,
#   'season': 'Summer',
#   'city': 'Barcelona',
#   'sport': 'Basketball',
#   'event': "Basketball Men's Basketball",
#   'medal': None},
#  {'name': 'A Lamusi',
#   'sex': 'M',
#   'age': 23.0,
#   'height': 170.0,
#   'weight': 60.0,
#   'country': 'China',
#   'noc': 'CHN',
#   'games': '2012 Summer',
#   'year': 2012,
#   'season': 'Summer',
#   'city': 'London',
#   'sport': 'Judo',
#   'event': "Judo Men's Extra-Lightweight",
#   'medal': None},
#  {'name': 'Gunnar Nielsen Aaby',
#   'sex': 'M',
#   'age': 24.0,
#   'height': None,
#   'weight': None,
#   'country': 'Denmark',
#   'noc': 'DEN',
#   'games': '1920 Summer',
#   'year': 1920,
#   'season': 'Summer',
#   'city': 'Antwerpen',
#   'sport': 'Football',
#   'event': "Football Men's Football",
#   'medal': None},
# ...

# %%
session.close()

# %%
# stmt = session.query(Athletes).statement
# df = pd.read_sql_query(stmt, conn)

# %%
# df.columns
# Out:
# Index(['sno', 'id', 'name', 'sex', 'age', 'height', 'weight', 'team', 'noc',
#        'games', 'year', 'season', 'city', 'sport', 'event', 'medal'],
#       dtype='object')

# %%
list(df.columns)[2:]
# Out:
# ['name',
#  'sex',
#  'age',
#  'height',
#  'weight',
#  'team',
#  'noc',
#  'games',
#  'year',
#  'season',
#  'city',
#  'sport',
#  'event',
#  'medal']

# %%
results = session.query(athletes.sno, athletes.id, athletes.name, athletes.sex, athletes.age, athletes.height, athletes.weight, athletes.team, athletes.noc, athletes.games, athletes.year, athletes.season, athletes.city, athletes.sport, athletes.event, athletes.medal).all()

# %%
all_athletes = []

# %%
for sno, id, name, sex,age, height, weight, team, noc, games, year, season, city, sport, event, medal in results:
    altlete_dict = {}
    altlete_dict["name"] = name
    altlete_dict["sex"] = sex
    altlete_dict["height"] = height
    altlete_dict["weight"] = weight
    altlete_dict["games"] = games
    altlete_dict["medal"] = medal
    altlete_dict["season"] = season
    altlete_dict["sport"] = sport
    all_athletes.append(altlete_dict)

# %%
# all_athletes

# %%
# stmt = db.session.query(Athletes).statement
# df = pd.read_sql_query(stmt, db.session.bind)

# %%
return jsonify(list(df.columns)[2:])
