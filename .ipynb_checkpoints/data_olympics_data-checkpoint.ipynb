# %%
import pandas as pd

# %% [markdown]
# ## Load

# %%
# Load data
sports_df = pd.read_csv('olympics_data.csv')
sports_df.head()
# Out:
#    sno  ID                      Name Sex   Age  Height  Weight      Country  \
# 0    0   1                 A Dijiang   M  24.0   180.0    80.0        China
# 1    1   2                  A Lamusi   M  23.0   170.0    60.0        China
# 2    2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN      Denmark
# 3    3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN      Denmark
# 4    4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# # Clean

# %%
# Checking to see count of datapoints
sports_df.count()
# Out:
# sno        271116
# ID         271116
# Name       271116
# Sex        271116
# Age        261642
# Height     210945
# Weight     208241
# Country    271116
# NOC        271116
# Games      271116
# Year       271116
# Season     271116
# City       271116
# Sport      271116
# Event      271116
# Medal       39783
# dtype: int64

# %%
# Dropping NaN
sports_df = sports_df.dropna(how='any')
sports_df.count()
# Out:
# sno        30181
# ID         30181
# Name       30181
# Sex        30181
# Age        30181
# Height     30181
# Weight     30181
# Country    30181
# NOC        30181
# Games      30181
# Year       30181
# Season     30181
# City       30181
# Sport      30181
# Event      30181
# Medal      30181
# dtype: int64

# %% [markdown]
# ## Female Sports

# %% [markdown]
# ### Gold

# %%
# Filtering for FEMALE, Age, Height, Weight, Team, Sport, Event, Medal (GOLD)

female_sports_df = sports_df.loc[(sports_df['Sex'] =='F') & (sports_df['Medal'] =='Gold'), :]
female_sports_df.head()
# Out:
#        sno   ID                                  Name Sex   Age  Height  \
# 1494  1494  832                 Nicola Virginia Adams   F  29.0   164.0
# 1495  1495  832                 Nicola Virginia Adams   F  33.0   164.0
# 1527  1527  846  Valerie Kasanita Adams-Vili (-Price)   F  23.0   193.0
# 1528  1528  846  Valerie Kasanita Adams-Vili (-Price)   F  27.0   193.0
# 1668  1668  925   Adenzia Aparecida Ferreira da Silva   F  25.0   187.0
#
#       Weight      Country  NOC        Games  Year  Season            City  \
# 1494    51.0           UK  GBR  2012 Summer  2012  Summer          London
# 1495    51.0           UK  GBR  2016 Summer  2016  Summer  Rio de Janeiro
# 1527   120.0  New Zealand  NZL  2008 Summer  2008  Summer         Beijing
# 1528   120.0  New Zealand  NZL  2012 Summer  2012  Summer          London
# 1668    65.0       Brazil  BRA  2012 Summer  2012  Summer          London
#
#            Sport                          Event Medal
# 1494      Boxing       Boxing Women's Flyweight  Gold
# 1495      Boxing       Boxing Women's Flyweight  Gold
# 1527   Athletics     Athletics Women's Shot Put  Gold
# 1528   Athletics     Athletics Women's Shot Put  Gold
# 1668  Volleyball  Volleyball Women's Volleyball  Gold

# %%
# Saving Dataframe into a csv file
female_sports_df.to_csv('Female-Sports/female_olympics_gold.csv', index=False)

# %% [markdown]
# ### Silver

# %%
# Filtering for FEMALE, Age, Height, Weight, Team, Sport, Event, Medal (SILVER)

female_sports_df = sports_df.loc[(sports_df['Sex'] =='F') & (sports_df['Medal'] =='Silver'), :]
female_sports_df.head()
# Out:
#      sno   ID                                     Name Sex   Age  Height  \
# 163  163   67  Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0
# 195  195   90                Tamila Rashidovna Abasova   F  21.0   163.0
# 286  286  153                    Monica Cecilia Abbott   F  23.0   191.0
# 311  311  165                      Nia Nicole Abdallah   F  20.0   175.0
# 677  677  394                               Irene Abel   F  19.0   160.0
#
#      Weight  Country  NOC        Games  Year  Season     City       Sport  \
# 163    80.0   Russia  RUS  2008 Summer  2008  Summer  Beijing   Athletics
# 195    60.0   Russia  RUS  2004 Summer  2004  Summer   Athina     Cycling
# 286    88.0      USA  USA  2008 Summer  2008  Summer  Beijing    Softball
# 311    56.0      USA  USA  2004 Summer  2004  Summer   Athina   Taekwondo
# 677    48.0  Germany  GDR  1972 Summer  1972  Summer   Munich  Gymnastics
#
#                                   Event   Medal
# 163     Athletics Women's Javelin Throw  Silver
# 195              Cycling Women's Sprint  Silver
# 286           Softball Women's Softball  Silver
# 311     Taekwondo Women's Featherweight  Silver
# 677  Gymnastics Women's Team All-Around  Silver

# %%
# Saving Dataframe into a csv file
female_sports_df.to_csv('Female-Sports/female_olympics_silver.csv', index=False)

# %% [markdown]
# ### Bronze

# %%
# Filtering for FEMALE, Age, Height, Weight, Team, Sport, Event, Medal (BRONZE)

female_sports_df = sports_df.loc[(sports_df['Sex'] =='F') & (sports_df['Medal'] =='Bronze'), :]
female_sports_df.head()
# Out:
#      sno   ID                                Name Sex   Age  Height  Weight  \
# 105  105   37                  Ann Kristin Aarnes   F  23.0   182.0    64.0
# 161  161   65                   Patimat Abakarova   F  21.0   165.0    49.0
# 476  476  259                          Reema Abdo   F  21.0   173.0    59.0
# 684  684  395                       Jennifer Abel   F  20.0   160.0    62.0
# 974  974  548  Yekaterina Konstantinovna Abramova   F  23.0   167.0    65.0
#
#         Country  NOC        Games  Year  Season            City  \
# 105      Norway  NOR  1996 Summer  1996  Summer         Atlanta
# 161  Azerbaijan  AZE  2016 Summer  2016  Summer  Rio de Janeiro
# 476      Canada  CAN  1984 Summer  1984  Summer     Los Angeles
# 684      Canada  CAN  2012 Summer  2012  Summer          London
# 974      Russia  RUS  2006 Winter  2006  Winter          Torino
#
#              Sport                                         Event   Medal
# 105       Football                     Football Women's Football  Bronze
# 161      Taekwondo                   Taekwondo Women's Flyweight  Bronze
# 476       Swimming  Swimming Women's 4 x 100 metres Medley Relay  Bronze
# 684         Diving       Diving Women's Synchronized Springboard  Bronze
# 974  Speed Skating   Speed Skating Women's Team Pursuit (6 laps)  Bronze

# %%
# Saving Dataframe into a csv file
female_sports_df.to_csv('Female-Sports/female_olympics_bronze.csv', index=False)

# %% [markdown]
# ## Female Sport Categories

# %%
# Finding all female sports categories 
unique_f_sports_df = female_sports_df['Sport']
unique_f_sports_df = pd.DataFrame(unique_f_sports_df)

# unique_f_sports_df.Sport.unique()

# %% [markdown]
# ## Female Sport Events

# %%
# Finding all female sport events
unique_f_events_df = female_sports_df['Event']
unique_f_events_df = pd.DataFrame(unique_f_events_df)

# unique_f_events_df.Event.unique()

# %% [markdown]
# ## Male Sports

# %% [markdown]
# ### Gold

# %%
# Filtering for MALE, Age, Height, Weight, Team, Sport, Event, Medal (GOLD)

male_sports_df = sports_df.loc[(sports_df['Sex'] =='M') & (sports_df['Medal'] =='Gold'), :]
male_sports_df.head()
# Out:
#     sno  ID                     Name Sex   Age  Height  Weight  Country  NOC  \
# 42   42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 44   44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 48   48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 60   60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway  NOR
# 73   73  20       Kjetil Andr Aamodt   M  30.0   176.0    85.0   Norway  NOR
#
#           Games  Year  Season            City          Sport  \
# 42  1948 Summer  1948  Summer          London     Gymnastics
# 44  1948 Summer  1948  Summer          London     Gymnastics
# 48  1948 Summer  1948  Summer          London     Gymnastics
# 60  1992 Winter  1992  Winter     Albertville  Alpine Skiing
# 73  2002 Winter  2002  Winter  Salt Lake City  Alpine Skiing
#
#                                Event Medal
# 42  Gymnastics Men's Team All-Around  Gold
# 44      Gymnastics Men's Horse Vault  Gold
# 48  Gymnastics Men's Pommelled Horse  Gold
# 60       Alpine Skiing Men's Super G  Gold
# 73       Alpine Skiing Men's Super G  Gold

# %%
# Saving Dataframe into a csv file
male_sports_df.to_csv('Male-Sports/male_olympics_gold.csv', index=False)

# %% [markdown]
# ### Silver

# %%
# Filtering for MALE, Age, Height, Weight, Team, Sport, Event, Medal (SILVER)

male_sports_df = sports_df.loc[(sports_df['Sex'] =='M') & (sports_df['Medal'] =='Silver'), :]
male_sports_df.head()
# Out:
#      sno  ID                  Name Sex   Age  Height  Weight      Country  \
# 63    63  20    Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway
# 67    67  20    Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway
# 92    92  30      Pepijn Aardewijn   M  26.0   189.0    72.0  Netherlands
# 175  175  73             Luc Abalo   M  31.0   182.0    86.0       France
# 186  186  84  Stephen Anthony Abas   M  26.0   165.0    55.0          USA
#
#      NOC        Games  Year  Season            City          Sport  \
# 63   NOR  1994 Winter  1994  Winter     Lillehammer  Alpine Skiing
# 67   NOR  1994 Winter  1994  Winter     Lillehammer  Alpine Skiing
# 92   NED  1996 Summer  1996  Summer         Atlanta         Rowing
# 175  FRA  2016 Summer  2016  Summer  Rio de Janeiro       Handball
# 186  USA  2004 Summer  2004  Summer          Athina      Wrestling
#
#                                         Event   Medal
# 63               Alpine Skiing Men's Downhill  Silver
# 67               Alpine Skiing Men's Combined  Silver
# 92     Rowing Men's Lightweight Double Sculls  Silver
# 175                   Handball Men's Handball  Silver
# 186  Wrestling Men's Featherweight, Freestyle  Silver

# %%
# Saving Dataframe into a csv file
male_sports_df.to_csv('Male-Sports/male_olympics_silver.csv', index=False)

# %% [markdown]
# ### Bronze

# %%
# Filtering for MALE, Age, Height, Weight, Team, Sport, Event, Medal (BRONZE)

male_sports_df = sports_df.loc[(sports_df['Sex'] =='M') & (sports_df['Medal'] =='Bronze'), :]
male_sports_df.head()
# Out:
#     sno  ID                      Name Sex   Age  Height  Weight  Country  NOC  \
# 40   40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41   41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 50   50  17   Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland  FIN
# 61   61  20        Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway  NOR
# 64   64  20        Kjetil Andr Aamodt   M  22.0   176.0    85.0   Norway  NOR
#
#           Games  Year  Season         City          Sport  \
# 40  2014 Winter  2014  Winter        Sochi     Ice Hockey
# 41  1948 Summer  1948  Summer       London     Gymnastics
# 50  1952 Summer  1952  Summer     Helsinki     Gymnastics
# 61  1992 Winter  1992  Winter  Albertville  Alpine Skiing
# 64  1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
#
#                                      Event   Medal
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze
# 50        Gymnastics Men's Team All-Around  Bronze
# 61        Alpine Skiing Men's Giant Slalom  Bronze
# 64             Alpine Skiing Men's Super G  Bronze

# %%
# Saving Dataframe into a csv file
male_sports_df.to_csv('Male-Sports/male_olympics_bronze.csv', index=False)

# %% [markdown]
# ## Male Sport Categories

# %%
# Finding all male sport categories 
unique_m_sports_df = male_sports_df['Sport']
unique_m_sports_df = pd.DataFrame(unique_m_sports_df)

# unique_m_sports_df.Sport.unique()

# %% [markdown]
# ## Male Sport Events

# %%
# Finding all male sport events
unique_m_events_df = male_sports_df['Event']
unique_m_events_df = pd.DataFrame(unique_m_events_df)

# unique_m_events_df.Event.unique()
