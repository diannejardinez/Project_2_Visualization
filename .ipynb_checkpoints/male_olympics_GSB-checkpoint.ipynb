# %%
import pandas as pd

# %%
# Load data
gold_male_sports_df = pd.read_csv('Male-Sports/male_olympics_gold.csv')
silver_male_sports_df = pd.read_csv('Male-Sports/male_olympics_silver.csv')
bronze_male_sports_df = pd.read_csv('Male-Sports/male_olympics_bronze.csv')

# %%
# Group by Event - Gold
gold_df_by_event = gold_male_sports_df.groupby(['Event', 'Season', 'Sex', 'Medal'])

# Find median for Age, Height, Weight
gold_df_med_by_event = gold_df_by_event.median()
gold_df_med_by_event[["Age", "Height", "Weight"]]
# Out:
#                                                                   Age  Height  \
# Event                                          Season Sex Medal
# Alpine Skiing Men's Combined                   Winter M   Gold   26.0   178.5
# Alpine Skiing Men's Downhill                   Winter M   Gold   24.0   183.0
# Alpine Skiing Men's Giant Slalom               Winter M   Gold   25.0   180.0
# Alpine Skiing Men's Slalom                     Winter M   Gold   24.0   180.0
# Alpine Skiing Men's Super G                    Winter M   Gold   27.5   180.0
# ...                                                               ...     ...
# Wrestling Men's Super-Heavyweight, Freestyle   Summer M   Gold   27.0   190.0
# Wrestling Men's Super-Heavyweight, Greco-Roman Summer M   Gold   26.0   193.0
# Wrestling Men's Unlimited Class, Greco-Roman   Summer M   Gold   26.0   159.0
# Wrestling Men's Welterweight, Freestyle        Summer M   Gold   25.0   171.0
# ...

# %%
# Saving Dataframe into a csv file and json file
gold_df_med_by_event.to_csv('Male-Events/olympics_male_gold_bodycomp_age.csv', index=True)
gold_df_med_by_event.to_json('Male-Events/olympics_male_gold_bodycomp_age.json')

# %%
# Group by Event - Silver
silver_df_by_event = silver_male_sports_df.groupby(['Event', 'Season', 'Sex', 'Medal'])

# Find median for Age, Height, Weight
silver_df_med_by_event = silver_df_by_event.median()
silver_df_med_by_event[["Age", "Height", "Weight"]]
# Out:
#                                                                    Age  \
# Event                                          Season Sex Medal
# Alpine Skiing Men's Combined                   Winter M   Silver  25.0
# Alpine Skiing Men's Downhill                   Winter M   Silver  27.0
# Alpine Skiing Men's Giant Slalom               Winter M   Silver  25.5
# Alpine Skiing Men's Slalom                     Winter M   Silver  25.5
# Alpine Skiing Men's Super G                    Winter M   Silver  27.5
# ...                                                                ...
# Wrestling Men's Middleweight, Greco-Roman      Summer M   Silver  25.0
# Wrestling Men's Super-Heavyweight, Freestyle   Summer M   Silver  23.5
# Wrestling Men's Super-Heavyweight, Greco-Roman Summer M   Silver  27.5
# Wrestling Men's Welterweight, Freestyle        Summer M   Silver  26.0
# Wrestling Men's Welterweight, Greco-Roman      Summer M   Silver  26.0
#
# ...

# %%
# Saving Dataframe into a csv file and json file
silver_df_med_by_event.to_csv('Male-Events/olympics_male_silver_bodycomp_age.csv', index=True)
silver_df_med_by_event.to_json('Male-Events/olympics_male_silver_bodycomp_age.json')

# %%
# Group by Event - Bronze
bronze_df_by_event = bronze_male_sports_df.groupby(['Event', 'Season', 'Sex', 'Medal'])

# Find median for Age, Height, Weight
bronze_df_med_by_event = bronze_df_by_event.median()
bronze_df_med_by_event[["Age", "Height", "Weight"]]
# Out:
#                                                                    Age  \
# Event                                          Season Sex Medal
# Alpine Skiing Men's Combined                   Winter M   Bronze  25.0
# Alpine Skiing Men's Downhill                   Winter M   Bronze  27.0
# Alpine Skiing Men's Giant Slalom               Winter M   Bronze  25.0
# Alpine Skiing Men's Slalom                     Winter M   Bronze  23.0
# Alpine Skiing Men's Super G                    Winter M   Bronze  26.0
# ...                                                                ...
# Wrestling Men's Middleweight, Greco-Roman      Summer M   Bronze  26.0
# Wrestling Men's Super-Heavyweight, Freestyle   Summer M   Bronze  27.0
# Wrestling Men's Super-Heavyweight, Greco-Roman Summer M   Bronze  26.5
# Wrestling Men's Welterweight, Freestyle        Summer M   Bronze  25.0
# Wrestling Men's Welterweight, Greco-Roman      Summer M   Bronze  25.5
#
# ...

# %%
# Saving Dataframe into a csv file and json file
bronze_df_med_by_event.to_csv('Male-Events/olympics_male_bronze_bodycomp_age.csv', index=True)
bronze_df_med_by_event.to_json('Male-Events/olympics_male_bronze_bodycomp_age.json')
